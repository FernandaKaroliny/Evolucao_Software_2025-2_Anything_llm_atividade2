# %%
# Instalar dependências
# !pip install -q sentence-transformers scikit-learn

# Importar bibliotecas
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans
import numpy as np


# Carregar modelo All-MiniLM-L6-v2 ------------------------------
model = SentenceTransformer('all-MiniLM-L6-v2')


# Ler arquivo entrada5.txt ------------------------------
with open('entrada5.txt', 'r', encoding='utf-8') as f:
    entrada = f.read()


linhas = [linha.strip() for linha in entrada.split('\n') if linha.strip()]


# Separar manualmente seções de branches e releases ---------------------------
branches = []
releases = []
modo = None
for linha in linhas:
    if linha.lower().startswith("branches"):
        modo = "branches"
        continue
    if linha.lower().startswith("releases"):
        modo = "releases"
        continue
    if modo == "branches":
        branches.append(linha)
    elif modo == "releases":
        releases.append(linha)


# Gerar embeddings ------------------------------
branch_embeddings = model.encode(branches)
release_embeddings = model.encode(releases)


# Agrupar releases e branches com KMeans ------------------------------
# Releases: cluster 2 (features vs patches)
kmeans_release = KMeans(n_clusters=2, random_state=42)
release_clusters = kmeans_release.fit_predict(release_embeddings)

# Branches: cluster 3 (master, features, bugs)
kmeans_branch = KMeans(n_clusters=3, random_state=42)
branch_clusters = kmeans_branch.fit_predict(branch_embeddings)


# Interpretar clusters para estratégia ------------------------------
# Releases
num_patches = sum(1 for c in release_clusters if c == 0)
num_features = sum(1 for c in release_clusters if c == 1)
if num_patches > 0 and num_features > 0:
    estrategia_releases = "Rapid Release (entregas frequentes de patches e features)"
else:
    estrategia_releases = "Release Train / LTS (poucos releases grandes ou regulares)"

# Branches
# Identificação simples baseada em nomes
master_branch = any("master" in b.lower() for b in branches)
feature_branch = any("feat" in b.lower() for b in branches)
bug_branch = any("bug" in b.lower() for b in branches)
if master_branch and feature_branch and bug_branch:
    fluxo_trabalho = "Gitflow simplificado (master para produção, branches curtas para features e bugs)"
else:
    fluxo_trabalho = "GitHub Flow (merge direto em master)"


# Resultados ------------------------------
print("=== Releases agrupados ===")
for r, c in zip(releases, release_clusters):
    print(f"[Cluster {c}] {r}")

print("\n=== Branches agrupados ===")
for b, c in zip(branches, branch_clusters):
    print(f"[Cluster {c}] {b}")

print("\n=== Estratégia de Releases sugerida ===")
print(estrategia_releases)

print("\n=== Modelo de Fluxo de Trabalho sugerido ===")
print(fluxo_trabalho)
# Out:
# === Releases agrupados ===
# [Cluster 0] v1.9.1 – Dec 9, 2025
# [Cluster 0] v1.9.0 – Oct 9, 2025
# [Cluster 0] v1.8.5 – Aug 14, 2025
# [Cluster 0] v1.8.4 – Jul 16, 2025
# [Cluster 0] v1.8.3 – Jul 9, 2025
# [Cluster 0] v1.8.2 – Jun 10, 2025
# [Cluster 0] v1.8.1 – May 5, 2025
# [Cluster 0] v1.8.0 – Apr 18, 2025
# [Cluster 0] v1.7.8 – Mar 26, 2025
# [Cluster 0] v1.7.6 – Mar 19, 2025
# [Cluster 0] v1.7.5 – Mar 4, 2025
# [Cluster 0] v1.7.4 – Feb 17, 2025
# [Cluster 1] v1.4.0 – Jan 29, 2025
# [Cluster 1] v1.3.0 – Nov 26, 2024
# [Cluster 1] v1.2.4 – Oct 24, 2024
# [Cluster 1] v1.2.3 – Oct 3, 2024
# [Cluster 1] v1.2.2 – Sep 11, 2024
# [Cluster 1] v1.2.1 – Aug 19, 2024
# [Cluster 1] v1.2.0 – Aug 7, 2024
# [Cluster 1] v1.1.1 – Aug 2, 2024
# [Cluster 1] v1.1.0 – Jul 31, 2024
# [Cluster 1] v1.0.0 – Jul 26, 2024
#
# === Branches agrupados ===
# [Cluster 1] 1.8.3-rerelease
# [Cluster 1] 1.9.1-rerelease
# [Cluster 2] 1029-feat-hf-serverless-inference-api
# [Cluster 2] 1086-feat-implement-normalized-input-fields
# [Cluster 2] 1297-feat-gemini-agent-support
# [Cluster 1] 1312-bug-usernames-should-not-be-case-sensitive-when-logging-in
# [Cluster 1] 1522-feat-chromadb-support
# [Cluster 1] 1536-bug-toggling-on-users-can-delete-workspaces-does-not-take-effect
# [Cluster 1] 1582-bug-lm-studio-does-not-allow-for-different-model-selection
# [Cluster 1] 1595-bug-unable-to-get-live-web-search-and-browsing-agent-working-using-google-custom-search-engine-error-getaddrinfo-enotfound-http-errno-3008
# [Cluster 2] 1656-feat-implement-tooltip-ui-designs
# [Cluster 0] 1686-feat-implement-winston-for-logging
# [Cluster 1] 1759-bug-ui-bug-fixes
# [Cluster 2] 1787-custom-roles-and-permissions
# [Cluster 2] 1873-feat-auto-add-and-watch-folder-for-document-uploads
# [Cluster 2] 2011-feat-bump-perplexity-models
# [Cluster 1] 2019-slash-command-keyboard-selection
# [Cluster 1] 2647-feat-hpp-header-for-a-c++-code-file-mime-addition
# [Cluster 2] 2827-feat-perplexity-citations
# [Cluster 2] 2866-feat-finally-a-gemini-models-endpoint
# [Cluster 1] 2995-feat-disable-temperature-setting-for-deepseek-r1-deepseek-reasoner-model
# [Cluster 1] 3147-bug-embedded-chat-widget---not-considering-query-mode-option-always-working-in-chat-mode
# [Cluster 0] 3209-feat-apiv1workspacestream-chat-sources-citations
# [Cluster 2] 3280-token-counting-server-side-truncation-improvements
# [Cluster 1] 3282-manager-view-models-workspace
# [Cluster 0] 3439-feat-call-variables-within-the-flow-api-block-url-field
# [Cluster 1] 3463-bug-agent-continues-to-run-if-request-failed-even-after-exit
# [Cluster 0] 3586-bug-agent-flow-function-description-provided-by-user-is-not-seen-in-the-llm-query
# [Cluster 2] 3901-bug-validfunccall-checks-optional-arguments
# [Cluster 2] 3921-feat-agent-skills-uiux-improvements
# [Cluster 1] 3955-feat-jinaai-embedder-provider-support
# [Cluster 1] 4136-feat-jan-as-a-backend-server-option
# [Cluster 2] 4172-feat-openai-o3-support
# [Cluster 1] 4184-provide-privacy-policy-links-in-onboarding
# [Cluster 1] 4210-bug-voice-to-text-overwrite
# [Cluster 1] 4325-sys-prompt-var-improvements
# [Cluster 0] 4391-feat-integrate-docker-model-runner-as-a-local-inferencing-provide
# [Cluster 1] 4431-validate-vector-database-connectioN
# [Cluster 1] 4431-validate-vector-database-connection
# [Cluster 2] 4497-feat-workspace-names
# [Cluster 1] 4508-agent-youtube-transcript-analysis
# [Cluster 1] 4559-feat-agent-web-search-enable-ordering-of-results
# [Cluster 1] 4572-bug-lmstudio-provided-llm-stopped-working-with-anything-llm-after-upgrading-to-190
# [Cluster 1] 4599-bug-ollama-race-condition-bug
# [Cluster 0] 4615-feat-disable-apidocs-with-environment-variable
# [Cluster 2] 4687-feat-refactor-vector-db-providers
# [Cluster 2] 4774-feat-refactor-collector-to-remove-fluent-ffmpeg-package
# [Cluster 1] 4792-feat-refactor-workspacepfp-image
# [Cluster 1] 644-bug-uploaded-file-name-does-not-match-the-displayed-file-name-after-the-upload
# [Cluster 0] add-jira-slack-data-connector
# [Cluster 0] agent-ui-mobile-styles
# [Cluster 1] desktop
# [Cluster 0] frontend-eslint
# [Cluster 2] keyboard-dev
# [Cluster 2] knowledge-graph-support
# [Cluster 2] lancedb-revert
# [Cluster 1] lightmode-dropdown-color-update
# [Cluster 1] master
# [Cluster 1] microsoft-foundry-provider
# [Cluster 2] new-landing-ui-poc
# [Cluster 2] office-extension-wip
# [Cluster 1] ollama-lmstudio-auto-context-window
# [Cluster 0] pg
# [Cluster 0] refactor-eslint-frontend
# [Cluster 2] render
# [Cluster 0] tasks
# [Cluster 2] vectordb-class-migration
# [Cluster 0] web-push-notifications-service
#
# === Estratégia de Releases sugerida ===
# Rapid Release (entregas frequentes de patches e features)
#
# === Modelo de Fluxo de Trabalho sugerido ===
# Gitflow simplificado (master para produção, branches curtas para features e bugs)
